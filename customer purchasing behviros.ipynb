# %% [markdown]
# <a href="https://colab.research.google.com/github/ehab079/datasciencecoursera/blob/main/customer%20purchasing%20behviros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sum(df.duplicated('RecipeId'))==0
# Out:
# True

# %%
df.shape
# Out:
# (7458, 3)

# %%
print(df.isnull().sum())
print(df.isnull().values.any())
print(df.isnull().values.sum())
# Out:
# RecipeName           0
# RecipeDescription    0
# RecipeId             0
# dtype: int64
# False
# 0

# %%
df=pd.read_csv('recipes.csv')
df.head()
# Out:
#            RecipeName                           RecipeDescription  RecipeId
# 0  FtL/Ham             Ham FtLong                                         1
# 1  FfB/Ham             Ham FtFbd                                          2
# 2  Six/Ham             Ham 6 inch                                         3
# 3  fBd/Ham             Ham FlatBd                                         4
# 4  Sld/Ham             Ham Salad                                          5

# %%
df.describe()
# Out:
#           RecipeId
# count  7458.000000
# mean   4084.605792
# std    2624.111954
# min       1.000000
# 25%    1910.250000
# 50%    3781.500000
# 75%    5909.500000
# max    9663.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c30c95cf-f384-4349-9d10-38b9163a0285" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c30c95cf-f384-4349-9d10-38b9163a0285">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('Customer Purchasing Behaviors.csv')
df.head()
# Out:
#    user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0        1   25          45000              200            4.5  North
# 1        2   34          55000              350            7.0  South
# 2        3   45          65000              500            8.0   West
# 3        4   22          30000              150            3.0   East
# 4        5   29          47000              220            4.8  North
#
#    purchase_frequency
# 0                  12
# 1                  18
# 2                  22
# 3                  10
# 4                  13

# %%
df.describe()
# Out:
#           user_id         age  annual_income  purchase_amount  loyalty_score  \
# count  238.000000  238.000000     238.000000       238.000000     238.000000
# mean   119.500000   38.676471   57407.563025       425.630252       6.794118
# std     68.848868    9.351118   11403.875717       140.052062       1.899047
# min      1.000000   22.000000   30000.000000       150.000000       3.000000
# 25%     60.250000   31.000000   50000.000000       320.000000       5.500000
# 50%    119.500000   39.000000   59000.000000       440.000000       7.000000
# 75%    178.750000   46.750000   66750.000000       527.500000       8.275000
# max    238.000000   55.000000   75000.000000       640.000000       9.500000
#
#        purchase_frequency
# count          238.000000
# mean            19.798319
# std              4.562884
# min             10.000000
# 25%             17.000000
# 50%             20.000000
# 75%             23.000000
# max             28.000000

# %%
sum(df.duplicated('user_id'))==0
# Out:
# True

# %%
df.shape
# Out:
# (238, 7)

# %%
df.isnull().sum()
df.isnull().values.any()
df.isnull().values.sum()
# Out:
# 0
